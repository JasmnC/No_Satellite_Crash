# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
sns.set_context('notebook')

RANDOM_SEED = 20090425

# %%
try:
    data = pd.read_csv('./Sattelite Data.csv')
except:
    print("bad data path")

# %%
data.head()
# Out:
#     OBJECT_NAME  OBJECT_ID                       EPOCH  MEAN_MOTION  \
# 0   CALSPHERE 1  1964-063C  2023-11-27T17:53:31.352064    13.746337
# 1   CALSPHERE 2  1964-063E  2023-11-27T18:05:40.703712    13.527724
# 2         LCS 1  1965-034C  2023-11-28T03:27:38.943936     9.893042
# 3     TEMPSAT 1  1965-065E  2023-11-27T15:12:53.788032    13.334961
# 4  CALSPHERE 4A  1965-065H  2023-11-28T12:02:57.261696    13.360113
#
#    ECCENTRICITY  INCLINATION  RA_OF_ASC_NODE  ARG_OF_PERICENTER  MEAN_ANOMALY  \
# 0      0.002562      90.1985         51.1482           227.1089      249.6671
# 1      0.002004      90.2145         54.6112            57.9803      102.2002
# 2      0.000514      32.1385        230.0181           345.0141       15.0203
# 3      0.006961      89.9455        215.0448           348.8673       28.5617
# 4      0.006834      89.9569        128.9741           210.8541      219.8240
#
#    EPHEMERIS_TYPE CLASSIFICATION_TYPE  NORAD_CAT_ID  ELEMENT_SET_NO  \
# ...
